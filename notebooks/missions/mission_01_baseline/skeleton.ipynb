# %% [markdown]
# # Mission 01: Initial LangChain Agent (Baseline Chatbot) - 실습 노트북
#
# 이 노트북은 첫 번째 미션을 진행하며 챗봇 에이전트를 LangChain으로 구축하는 실습 가이드입니다.

# %%
# 1. 필요한 라이브러리 및 환경 로드
import sys
import os
from dotenv import load_dotenv

# 작업 디렉토리 싱크 정합
if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

sys.path.append(os.path.abspath("src"))
sys.path.append(os.path.abspath("app"))
load_dotenv(override=True)

from app.utils.llm import get_llm
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage

# %% [markdown]
# ### [미션 1] 에이전트 인스턴스 완성하기
#
# 아래 빈 칸에 `get_llm`과 `create_agent`를 활용하여 에이전트를 완성하세요.

# %%
# TODO: get_llm을 호출하여 'openai:gpt-4o' 또는 'google_vertexai:gemini-2.5-pro' 모델을 로드하세요.
llm = None

# TODO: create_agent를 호출하여 빈 도구 리스트와 함께 에이전트를 생성하세요.
agent = None

if agent is not None:
    print("✅ 에이전트 생성 성공!")
else:
    print("❌ 에이전트 생성 실패!")

# %% [markdown]
# ### [미션 2] 에이전트 호출 검증
#
# 완성된 에이전트의 대화 루프를 호출하여 결과를 검증합니다.

# %%
# 에이전트 실행 테스트
if agent:
    res = agent.invoke({"messages": [HumanMessage(content="안녕하세요! 오늘 하루는 어때요?")]})
    print("답변:", res["messages"][-1].content)
else:
    print("에이전트가 존재하지 않습니다.")
